# %% [markdown]
# # Project Description

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# I love math! In high school, my love for math truly flourished. For a little while in high school, I thought about being a Calculus professor because I loved it so much! I love the reliabilty of the numbers, the rules of Algebra, and it was always so satisfying solving for limits in Calculus! I really started to improve in my courses the better at got at mental math and basic arithmetic. You can't get better at something if you don't have the basics down!
#
# In this project, my goal is to improve the user's arithmetic, mental math, as well as problem solving using pencil and paper if need be.
#
# To do this I created 10 functions to create the game. I started by importing the module, Random, as well as a Random Module method called randint which returns a random integer from a specified range. I then defined two variables, correct_response and wrong_response containing lists of phrases (strings) that I could use when the user inputs their answer.
#
# The first function I defined is called input_check that loops over the user's inputs to make sure that the inputs are within the bounds I defined. Meaning, the user can only input numbers 1-7 to continue with the game and if they enter a number other than those, letters, or symbols, the code will will ask the user to choose one of the specified options until they do. The function game_options is used repeatedly to give the user the choice of which type of math problem they would like to practice. The function game_intro is presented and is called to start the game.It is seen just at the beginning to introduce the game and provide the instructions and then the function game_options is used for the first time for the user to select an option.
#
# Based on the selection the user makes, if they choose 1, the addition function is called. For 2, the subtraction function is called. For 3, the multiplication function is called. For 4, the division function is called. For 5, the squares function is called. For 6, the square root function is called, and for 7, the game will end. In each of these functions, randint method is used for different problems to be asked for each category of math problems. If the user is correct, that message will pop up and if they get it wrong, that message will show along with the correct answer so they learn for next time.
#
# To start the game the user must call game_intro and to continue playing, follow the instructions presented.
#
#
#
# If I more time I would have implemented a scoring system with a total and a percent correct at the end of the quiz so that the player could know their score and try to beat it as they continued to practice.

# %% [markdown]
# ## Project Code
#
# If it makes sense for your project, you can have code and outputs here in the notebook as well.

# %%
from my_module.functions import game_intro

#Code Tests
from my_module.test_functions import addition_test
from my_module.test_functions import subtraction_test
from my_module.test_functions import multiplication_test
from my_module.test_functions import division_test
from my_module.test_functions import squares_test
from my_module.test_functions import square_root_test

# %%
#Example of the played math game below
game_intro()
# Out:
# WELCOME TO MATH PRACTICE!
# Practice your mental math abilities, use a paper and pencil if you need, and maybe try to improve your speed!
# Which would you like to start with?
# 1 - addition
# 2 - subtraction
# 3 - multiplication
# 4 - division
# 5 - squares
# 6 - square root
# 7 - Exit Game.
# 1
# What is 38+79?
# Please enter ONLY a whole number or decimal.
#  117
# Awesome!
# Choose your next topic.
# 1 - addition
# 2 - subtraction
# 3 - multiplication
# 4 - division
# 5 - squares
# 6 - square root
# 7 - Exit Game.
# 2
# What is 9-88?
# Please enter ONLY a whole number or decimal.
#  -79
# Awesome!
# Choose your next topic.
# 1 - addition
# 2 - subtraction
# 3 - multiplication
# 4 - division
# 5 - squares
# 6 - square root
# 7 - Exit Game.
# 3
# What is 73x54?
# Please enter ONLY a whole number or decimal.
#  1234
# Not quite. Keep Practicing!
# The answer is 3942.
# Choose your next topic.
# 1 - addition
# 2 - subtraction
# 3 - multiplication
# 4 - division
# 5 - squares
# ...

# %% [markdown]
# #### Extra Credit (*optional*)
#
# Before this class, I had zero experience using python. I tried taking this course over the summer a few years ago but couldn't figure out how to download the software to take the course and I gave up and didn't take it. This year I didn't give up and learned so much because of it! From having no experience, to now, I feel very confident in my python abilities. Though I consider myself a beginner still, I feel good about reading and writing code and I feel that I have the building blocks to learn more complicated ways to code!
#
# I wasn't sure how I was going to go above and beyond for this project with my level of knowledge but if I were to say anything, I think I went above and beyond in my project in learning about and using methods we didn't use in class or those that were solely introduced in class. One was, for when the user gets an answer correct or incorrect, I wrote code that would return a random phrase from my lists I created of phrases for right and wrong answers. I did this using the random.choice method which was introduced to us in class but for my purposes, I had to really research and try to adapt it to work in my code properly. I also used a try block which was introduced to me and got some help from Professor Ellis. I felt that I worked very hard to get the try block to work with my code to make my game function properly. And lastly, I feel that I went above and beyond by writing 10 functions with 6 of them being different math categories to make my game more fun and could extend my user's practice. I think my game would have worked fine with 2 or 3 math categories but I wanted to put in the extra time and effort to make it longer and provide more options.
#
# I am so happy that I challenged myself by doing this project. I was so close to just doing the final exam because I knew I could study for that and be prepared, but I took the risk of trying this on my own and I am so glad I did! Because now, I know that have the skills to do this and because I was able to do this project, I am looking at python certification courses and am seriously considering a career where I could work with python!
